# %%
import requests
import tarfile
import sys
import os 
import scipy
import cv2
from matplotlib import pyplot as plt
from scipy import io
import numpy as np

# %%
#Choose n number of pictures
#n = sys.argv[1]
n=5

# %%
#Tar file must be in same directory as script
tar_file = 'BSR_bsds500.tgz'
tar = tarfile.open(tar_file,'r')
tar.extractall()
tar.close()
#tar file has been extracted, now lets load some images!

# %%
ground_truth_train = 'BSR/BSDS500/data/groundTruth/train/'
train_images = 'BSR/BSDS500/data/images/train/'
train_grfiles = os.listdir(ground_truth_train)
train_orfiles = os.listdir(train_images)
size_images = len(train_files)

# %%
#Lets choose some N random images 
images_escogidas = np.random.randint(0,size_images,int(n))
imagenes_finales = set(images_escogidas)
tam_random = len(imagenes_finales)

# %%
#Remember random can generate duplicates 
if tam_random < int(n):
    print('Random genero imagenes duplicadas :(')
os.mkdir('out')

# %%
diccionario = {}
for index in imagenes_finales:
    ori  = plt.imread(train_images+str(train_orfiles[index]))
    ori  = cv2.resize(ori, (256,256))
    tes  = io.loadmat(ground_truth_train+str(train_grfiles[index]))
    grou = tes['groundTruth']
    plt.imshow(ori)
    plt.imsave('out/'+str(train_orfiles[index])+str(ind)+'-seg.png',ori)
    plt.show()
    obj = []
    for ind, i in enumerate(grou[0]): 
        #print(train_grfiles[index])
        #print(ind)
        ch_s = cv2.resize( i[0][0][0], (256, 256))
        plt.imshow(ch_s,cmap='gray')
        plt.imsave('out/'+str(train_grfiles[index])+str(ind)+'-seg.png',ch_s)
        plt.show()
        ch_b = cv2.resize( i[0][0][1], (256, 256))
                            
        plt.imshow(ch_b,cmap='gray')
        plt.imsave('out/'+str(train_grfiles[index])+str(ind)+'-bou.png',ch_b)
        plt.show()
        obj.append('out/'+str(train_grfiles[index])+str(ind)+'-seg.png')
        obj.append('out/'+str(train_grfiles[index])+str(ind)+'-bou.png')
    diccionario['out/'+str(train_orfiles[index])+str(ind)+'-seg.png'] = obj
    
np.save('diccionario_ims.npz',diccionario)
# Out:
# {'out/103041.jpg5-seg.png': ['out/103041.mat0-seg.png', 'out/103041.mat0-bou.png', 'out/103041.mat1-seg.png', 'out/103041.mat1-bou.png', 'out/103041.mat2-seg.png', 'out/103041.mat2-bou.png', 'out/103041.mat3-seg.png', 'out/103041.mat3-bou.png', 'out/103041.mat4-seg.png', 'out/103041.mat4-bou.png', 'out/103041.mat5-seg.png', 'out/103041.mat5-bou.png'], 'out/301007.jpg4-seg.png': ['out/301007.mat0-seg.png', 'out/301007.mat0-bou.png', 'out/301007.mat1-seg.png', 'out/301007.mat1-bou.png', 'out/301007.mat2-seg.png', 'out/301007.mat2-bou.png', 'out/301007.mat3-seg.png', 'out/301007.mat3-bou.png', 'out/301007.mat4-seg.png', 'out/301007.mat4-bou.png'], 'out/108041.jpg4-seg.png': ['out/108041.mat0-seg.png', 'out/108041.mat0-bou.png', 'out/108041.mat1-seg.png', 'out/108041.mat1-bou.png', 'out/108041.mat2-seg.png', 'out/108041.mat2-bou.png', 'out/108041.mat3-seg.png', 'out/108041.mat3-bou.png', 'out/108041.mat4-seg.png', 'out/108041.mat4-bou.png'], 'out/372047.jpg4-seg.png': ['out/372047.mat0-seg.png', 'out/372047.mat0-bou.png', 'out/372047.mat1-seg.png', 'out/372047.mat1-bou.png', 'out/372047.mat2-seg.png', 'out/372047.mat2-bou.png', 'out/372047.mat3-seg.png', 'out/372047.mat3-bou.png', 'out/372047.mat4-seg.png', 'out/372047.mat4-bou.png'], 'out/138032.jpg4-seg.png': ['out/138032.mat0-seg.png', 'out/138032.mat0-bou.png', 'out/138032.mat1-seg.png', 'out/138032.mat1-bou.png', 'out/138032.mat2-seg.png', 'out/138032.mat2-bou.png', 'out/138032.mat3-seg.png', 'out/138032.mat3-bou.png', 'out/138032.mat4-seg.png', 'out/138032.mat4-bou.png']}
